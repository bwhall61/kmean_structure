# %% [markdown]
# # Imports

# %%
import numpy as np

# %% [markdown]
# # Load in tmalign scores

# %%
m = np.loadtxt('final_val.txt')

# %%
m.reshape(16,16)
# Out:
# array([[1.     , 0.99929, 0.27139, 0.33176, 0.33031, 0.28012, 0.28419,
#         0.31319, 0.32193, 0.2669 , 0.32958, 0.32912, 0.37645, 0.29963,
#         0.35702, 0.3636 ],
#        [0.99929, 1.     , 0.27385, 0.33126, 0.33172, 0.28114, 0.29481,
#         0.3118 , 0.32354, 0.27103, 0.32233, 0.32219, 0.3757 , 0.30464,
#         0.35581, 0.36542],
#        [0.27139, 0.27385, 1.     , 0.35916, 0.33096, 0.29082, 0.54596,
#         0.27969, 0.43428, 0.90676, 0.33771, 0.33766, 0.44132, 0.51907,
#         0.43929, 0.45317],
#        [0.33176, 0.33126, 0.35916, 1.     , 0.38148, 0.27507, 0.25972,
#         0.29013, 0.29605, 0.34225, 0.38915, 0.38855, 0.30538, 0.33695,
#         0.25325, 0.39834],
#        [0.33031, 0.33172, 0.33096, 0.38148, 1.     , 0.29529, 0.33152,
#         0.2858 , 0.36264, 0.34904, 0.9949 , 0.99383, 0.42322, 0.31922,
#         0.39876, 0.39434],
#        [0.28012, 0.28114, 0.29082, 0.27507, 0.29529, 1.     , 0.25249,
# ...
